# %% [markdown]
# ### RFM 분석 실습
# - Recency: 얼마나 최근에 구매했는가
# - Frequency: 얼마나 자주 구매했는가
# - Monetary: 얼마나 많은 금액을 지출했는가

# %% [markdown]
# ### 고객 분석
# - InvoiceNo: 거래 번호
# - StockCode: 상품 코드
# - Description: 상품명
# - InvoiceDate: 거래 날짜
# - UnitPrice: 상품 단가
# - CustomerID: 고객 번호
# - Country: 국가명

# %%
import pandas as pd
import numpy as np

co_df = pd.read_csv('./datasets/customer_invoice_data.csv')
co_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
co_df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...                 ...        ...         ...             ...
# 541904  12/9/2011 12:50       0.85     12680.0          France
# 541905  12/9/2011 12:50       2.10     12680.0          France
# 541906  12/9/2011 12:50       4.15     12680.0          France
# 541907  12/9/2011 12:50       4.15     12680.0          France
# 541908  12/9/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
# co_df.duplicated().sum()

# %%
# co_df.drop_duplicates(inplace=True)
# co_df

# %%
co_df.columns = ['invoice', 'code', 'description', 'quantity','date' ,'price', 'id','country']
co_df
# Out:
#        invoice    code                          description  quantity  \
# 0       536365  85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365   71053                  WHITE METAL LANTERN         6
# 2       536365  84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365  84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365  84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...     ...                                  ...       ...
# 541904  581587   22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905  581587   22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906  581587   23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907  581587   23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908  581587   22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                    date  price       id         country
# 0        12/1/2010 8:26   2.55  17850.0  United Kingdom
# 1        12/1/2010 8:26   3.39  17850.0  United Kingdom
# 2        12/1/2010 8:26   2.75  17850.0  United Kingdom
# 3        12/1/2010 8:26   3.39  17850.0  United Kingdom
# 4        12/1/2010 8:26   3.39  17850.0  United Kingdom
# ...                 ...    ...      ...             ...
# 541904  12/9/2011 12:50   0.85  12680.0          France
# 541905  12/9/2011 12:50   2.10  12680.0          France
# 541906  12/9/2011 12:50   4.15  12680.0          France
# 541907  12/9/2011 12:50   4.15  12680.0          France
# 541908  12/9/2011 12:50   4.95  12680.0          France
#
# [541909 rows x 8 columns]

# %%
co_df.drop(columns=['description'], inplace=True)
co_df
# Out:
#        invoice    code  quantity             date  price       id  \
# 0       536365  85123A         6   12/1/2010 8:26   2.55  17850.0
# 1       536365   71053         6   12/1/2010 8:26   3.39  17850.0
# 2       536365  84406B         8   12/1/2010 8:26   2.75  17850.0
# 3       536365  84029G         6   12/1/2010 8:26   3.39  17850.0
# 4       536365  84029E         6   12/1/2010 8:26   3.39  17850.0
# ...        ...     ...       ...              ...    ...      ...
# 541904  581587   22613        12  12/9/2011 12:50   0.85  12680.0
# 541905  581587   22899         6  12/9/2011 12:50   2.10  12680.0
# 541906  581587   23254         4  12/9/2011 12:50   4.15  12680.0
# 541907  581587   23255         4  12/9/2011 12:50   4.15  12680.0
# 541908  581587   22138         3  12/9/2011 12:50   4.95  12680.0
#
#                country
# 0       United Kingdom
# 1       United Kingdom
# 2       United Kingdom
# 3       United Kingdom
# 4       United Kingdom
# ...                ...
# 541904          France
# 541905          France
# 541906          France
# 541907          France
# 541908          France
#
# [541909 rows x 7 columns]

# %%
# co_df.dropna(subset=['id'], inplace=True)
# co_df

# %%
# ID 열에서 결측치를 찾아서 결측치 개수 계산
null_id_count = co_df['id'].isnull().sum()

# 결과 출력
print("결측치 개수:", null_id_count)
# Out:
# 결측치 개수: 135080

# %%
co_df['id'].value_counts()
co_df['id'].count()
# Out:
# 406829

# %%
co_df['id'].value_counts()
# Out:
# id
# 17841.0    7983
# 14911.0    5903
# 14096.0    5128
# 12748.0    4642
# 14606.0    2782
#            ...
# 15070.0       1
# 15753.0       1
# 17065.0       1
# 16881.0       1
# 16995.0       1
# Name: count, Length: 4372, dtype: int64

# %%
# 결측치 검사 결과description, id에 각각 1454, 135080이 나왔다. 
co_df.isnull().sum()
co_df[["id"]].describe().T
# Out:
#        count         mean          std      min      25%      50%      75%  \
# id  406829.0  15287.69057  1713.600303  12346.0  13953.0  15152.0  16791.0
#
#         max
# id  18287.0

# %%
co_df.value_counts()
# Out:
# invoice  code   quantity  date              price  id       country
# 555524   22698   1        6/5/2011 11:37    2.95   16923.0  United Kingdom    20
#          22697   1        6/5/2011 11:37    2.95   16923.0  United Kingdom    12
# 572861   22775   12       10/26/2011 12:46  1.25   14102.0  United Kingdom     8
# 572344   M       48       10/24/2011 10:43  1.50   14607.0  United Kingdom     6
# 578289   23395   1        11/23/2011 14:07  3.75   17841.0  United Kingdom     6
#                                                                               ..
# 553915   21165   12       5/19/2011 19:51   1.69   18225.0  United Kingdom     1
#          21080   12       5/19/2011 19:51   0.85   18225.0  United Kingdom     1
#          21078   12       5/19/2011 19:51   0.85   18225.0  United Kingdom     1
# 553913   85152   3        5/19/2011 19:47   2.10   18109.0  United Kingdom     1
# C581569  84978  -1        12/9/2011 11:58   1.25   17315.0  United Kingdom     1
# Name: count, Length: 401602, dtype: int64

# %%
import numpy as np

Q1 = co_df.describe().T.loc['price', '25%']
Q3 = co_df.describe().T.loc['price', '75%']

iqr = Q3 - Q1

lower_bound = Q1 - iqr * 1.5
uppper_bound = Q3 + iqr * 1.5

if lower_bound < 0:
    lower_bound = 0

print(f'정상치 범위: {lower_bound} ~ {uppper_bound}')
# Out:
# 정상치 범위: 0 ~ 8.45

# %%
# co_df['date'] = pd.to_datetime(co_df['date'])
# co_df.sort_values(['date'], ascending=False)

# %%
co_df = co_df[co_df['quantity'] >= 0]
co_df
# Out:
#        invoice    code  quantity             date  price       id  \
# 0       536365  85123A         6   12/1/2010 8:26   2.55  17850.0
# 1       536365   71053         6   12/1/2010 8:26   3.39  17850.0
# 2       536365  84406B         8   12/1/2010 8:26   2.75  17850.0
# 3       536365  84029G         6   12/1/2010 8:26   3.39  17850.0
# 4       536365  84029E         6   12/1/2010 8:26   3.39  17850.0
# ...        ...     ...       ...              ...    ...      ...
# 541904  581587   22613        12  12/9/2011 12:50   0.85  12680.0
# 541905  581587   22899         6  12/9/2011 12:50   2.10  12680.0
# 541906  581587   23254         4  12/9/2011 12:50   4.15  12680.0
# 541907  581587   23255         4  12/9/2011 12:50   4.15  12680.0
# 541908  581587   22138         3  12/9/2011 12:50   4.95  12680.0
#
#                country
# 0       United Kingdom
# 1       United Kingdom
# 2       United Kingdom
# 3       United Kingdom
# 4       United Kingdom
# ...                ...
# 541904          France
# 541905          France
# 541906          France
# 541907          France
# 541908          France
#
# [531285 rows x 7 columns]

# %%
co_df['date'] = pd.to_datetime(co_df['date']).dt.strftime('%Y/%m/%d')
co_df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16372\2650994710.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   co_df['date'] = pd.to_datetime(co_df['date']).dt.strftime('%Y/%m/%d')
#        invoice    code  quantity        date  price       id         country
# 0       536365  85123A         6  2010/12/01   2.55  17850.0  United Kingdom
# 1       536365   71053         6  2010/12/01   3.39  17850.0  United Kingdom
# 2       536365  84406B         8  2010/12/01   2.75  17850.0  United Kingdom
# 3       536365  84029G         6  2010/12/01   3.39  17850.0  United Kingdom
# 4       536365  84029E         6  2010/12/01   3.39  17850.0  United Kingdom
# ...        ...     ...       ...         ...    ...      ...             ...
# 541904  581587   22613        12  2011/12/09   0.85  12680.0          France
# 541905  581587   22899         6  2011/12/09   2.10  12680.0          France
# 541906  581587   23254         4  2011/12/09   4.15  12680.0          France
# 541907  581587   23255         4  2011/12/09   4.15  12680.0          France
# 541908  581587   22138         3  2011/12/09   4.95  12680.0          France
#
# [531285 rows x 7 columns]

# %%
# 'date' 열을 복사하여 새로운 데이터프레임에 할당
co_df_copy = co_df.copy()

# 'date' 열의 값을 일 수로 변환하여 새로운 열에 저장
co_df['date'] = (pd.to_datetime('2011-12-09') - pd.to_datetime(co_df_copy['date'])).dt.days


# 결과 확인
print(co_df)
co_df
# Out:
#        invoice    code  quantity  date  price       id         country
# 0       536365  85123A         6   373   2.55  17850.0  United Kingdom
# 1       536365   71053         6   373   3.39  17850.0  United Kingdom
# 2       536365  84406B         8   373   2.75  17850.0  United Kingdom
# 3       536365  84029G         6   373   3.39  17850.0  United Kingdom
# 4       536365  84029E         6   373   3.39  17850.0  United Kingdom
# ...        ...     ...       ...   ...    ...      ...             ...
# 541904  581587   22613        12     0   0.85  12680.0          France
# 541905  581587   22899         6     0   2.10  12680.0          France
# 541906  581587   23254         4     0   4.15  12680.0          France
# 541907  581587   23255         4     0   4.15  12680.0          France
# 541908  581587   22138         3     0   4.95  12680.0          France
#
# [531285 rows x 7 columns]
# C:\Users\user\AppData\Local\Temp\ipykernel_16372\1484619336.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   co_df['date'] = (pd.to_datetime('2011-12-09') - pd.to_datetime(co_df_copy['date'])).dt.days
#        invoice    code  quantity  date  price       id         country
# 0       536365  85123A         6   373   2.55  17850.0  United Kingdom
# 1       536365   71053         6   373   3.39  17850.0  United Kingdom
# 2       536365  84406B         8   373   2.75  17850.0  United Kingdom
# 3       536365  84029G         6   373   3.39  17850.0  United Kingdom
# 4       536365  84029E         6   373   3.39  17850.0  United Kingdom
# ...        ...     ...       ...   ...    ...      ...             ...
# 541904  581587   22613        12     0   0.85  12680.0          France
# 541905  581587   22899         6     0   2.10  12680.0          France
# 541906  581587   23254         4     0   4.15  12680.0          France
# 541907  581587   23255         4     0   4.15  12680.0          France
# 541908  581587   22138         3     0   4.95  12680.0          France
#
# [531285 rows x 7 columns]

# %%
# co_df['date'] = pd.to_datetime(co_df['date']).apply(lambda x: (pd.to_datetime('2011-12-09') - x).days)

# %%
co_df
# 데이트 값 구함
# Out:
#        invoice    code  quantity  date  price       id         country
# 0       536365  85123A         6   373   2.55  17850.0  United Kingdom
# 1       536365   71053         6   373   3.39  17850.0  United Kingdom
# 2       536365  84406B         8   373   2.75  17850.0  United Kingdom
# 3       536365  84029G         6   373   3.39  17850.0  United Kingdom
# 4       536365  84029E         6   373   3.39  17850.0  United Kingdom
# ...        ...     ...       ...   ...    ...      ...             ...
# 541904  581587   22613        12     0   0.85  12680.0          France
# 541905  581587   22899         6     0   2.10  12680.0          France
# 541906  581587   23254         4     0   4.15  12680.0          France
# 541907  581587   23255         4     0   4.15  12680.0          France
# 541908  581587   22138         3     0   4.95  12680.0          France
#
# [531285 rows x 7 columns]

# %%
# # # Recency 구하기 
rfm_r = co_df.groupby('id')['date'].min().reset_index()
rfm_r.columns = ['id', 'Recency']
# 데이트 형식 변경 


#Frequency 구하기 
# rfm_f = co_df.groupby('id')['code'].value_counts().reset_index()
rfm_f = co_df['id'].value_counts().reset_index()
rfm_f.columns = ['id', 'Frequency']

# # Monetary 구하기 
rfm_m = co_df.groupby('id')['price'].sum().reset_index()
rfm_m.columns = ['id', 'Monetary']
rfm_m




rfm = pd.merge(rfm_r, rfm_m, on='id')
rfm = pd.merge(rfm, rfm_f, on='id')
rfm
# Out:
#            id  Recency  Monetary  Frequency
# 0     12346.0      325      1.04          1
# 1     12347.0        2    481.21        182
# 2     12348.0       75    178.71         31
# 3     12349.0       18    605.10         73
# 4     12350.0      310     65.30         17
# ...       ...      ...       ...        ...
# 4334  18280.0      277     47.65         10
# 4335  18281.0      180     39.36          7
# 4336  18282.0        7     62.39         12
# 4337  18283.0        3   1220.93        756
# 4338  18287.0       42    104.55         70
#
# [4339 rows x 4 columns]

# %%
# co_df = co_df.drop(columns=['code'], axis=1)
co_df
# Out:
#        invoice    code  quantity  date  price       id         country
# 0       536365  85123A         6   373   2.55  17850.0  United Kingdom
# 1       536365   71053         6   373   3.39  17850.0  United Kingdom
# 2       536365  84406B         8   373   2.75  17850.0  United Kingdom
# 3       536365  84029G         6   373   3.39  17850.0  United Kingdom
# 4       536365  84029E         6   373   3.39  17850.0  United Kingdom
# ...        ...     ...       ...   ...    ...      ...             ...
# 541904  581587   22613        12     0   0.85  12680.0          France
# 541905  581587   22899         6     0   2.10  12680.0          France
# 541906  581587   23254         4     0   4.15  12680.0          France
# 541907  581587   23255         4     0   4.15  12680.0          France
# 541908  581587   22138         3     0   4.95  12680.0          France
#
# [531285 rows x 7 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
rfm[['Recency', 'Frequency', 'Monetary']] = \
                                    scaler.fit_transform(rfm[['Recency', 'Frequency', 'Monetary']])

# %%
# 최근일 수록 숫자가 더 작게 나오기 때문에, 1을 빼준 값으로 점수를 계산한다.
rfm['Recency'] = 1 - rfm['Recency']
rfm
# Out:
#         id  Recency  Monetary  Frequency
# 0  12540.0      1.0       0.0        0.0

# %%
# RFM 점수 계산
rfm['TotalScore'] = rfm[['Recency', 'Frequency', 'Monetary']].sum(axis=1)
rfm
# Out:
#            id   Recency  Monetary  Frequency  TotalScore
# 0     12346.0  0.871314  0.000031   0.000000    0.871345
# 1     12347.0  0.005362  0.014437   0.023069    0.042868
# 2     12348.0  0.201072  0.005361   0.003824    0.210257
# 3     12349.0  0.048257  0.018153   0.009177    0.075588
# 4     12350.0  0.831099  0.001959   0.002039    0.835098
# ...       ...       ...       ...        ...         ...
# 4334  18280.0  0.742627  0.001430   0.001147    0.745204
# 4335  18281.0  0.482574  0.001181   0.000765    0.484519
# 4336  18282.0  0.018767  0.001872   0.001402    0.022040
# 4337  18283.0  0.008043  0.036629   0.096227    0.140899
# 4338  18287.0  0.112601  0.003137   0.008794    0.124531
#
# [4339 rows x 5 columns]

# %%
co_df.isnull().sum()
# Out:
# invoice          0
# code             0
# quantity         0
# date             0
# price            0
# id          133361
# country          0
# dtype: int64

# %%
co_rfm_df = pd.merge(co_df, rfm, on='id')
co_rfm_df
# Out:
#        invoice    code  quantity  date  price       id         country  \
# 0       536365  85123A         6   373   2.55  17850.0  United Kingdom
# 1       536365   71053         6   373   3.39  17850.0  United Kingdom
# 2       536365  84406B         8   373   2.75  17850.0  United Kingdom
# 3       536365  84029G         6   373   3.39  17850.0  United Kingdom
# 4       536365  84029E         6   373   3.39  17850.0  United Kingdom
# ...        ...     ...       ...   ...    ...      ...             ...
# 397919  581578   22993        12     0   1.25  12713.0         Germany
# 397920  581578   22907        12     0   0.85  12713.0         Germany
# 397921  581578   22908        12     0   0.85  12713.0         Germany
# 397922  581578   23215        12     0   2.08  12713.0         Germany
# 397923  581578   22736        10     0   1.65  12713.0         Germany
#
#          Recency  Monetary  Frequency  TotalScore
# 0       0.997319  0.035288   0.037726    1.070333
# 1       0.997319  0.035288   0.037726    1.070333
# 2       0.997319  0.035288   0.037726    1.070333
# 3       0.997319  0.035288   0.037726    1.070333
# 4       0.997319  0.035288   0.037726    1.070333
# ...          ...       ...        ...         ...
# 397919  0.000000  0.002854   0.004716    0.007570
# 397920  0.000000  0.002854   0.004716    0.007570
# 397921  0.000000  0.002854   0.004716    0.007570
# 397922  0.000000  0.002854   0.004716    0.007570
# 397923  0.000000  0.002854   0.004716    0.007570
#
# [397924 rows x 11 columns]

# %%
real_df = co_rfm_df.groupby('id')[['invoice','code','quantity','date','price','country','TotalScore']].first().reset_index()
display(real_df)
# Out:
#            id invoice   code  quantity  date  price         country  \
# 0     12346.0  541431  23166     74215   325   1.04  United Kingdom
# 1     12347.0  537626  85116        12   367   2.10         Iceland
# 2     12348.0  539318  84992        72   358   0.55         Finland
# 3     12349.0  577609  23112         2    18   7.50           Italy
# 4     12350.0  543037  21908        12   310   2.10          Norway
# ...       ...     ...    ...       ...   ...    ...             ...
# 4334  18280.0  545712  82484         3   277   7.90  United Kingdom
# 4335  18281.0  556464  22037        12   180   0.42  United Kingdom
# 4336  18282.0  562525  21270         1   126  12.75  United Kingdom
# 4337  18283.0  540350  22356         1   337   0.85  United Kingdom
# 4338  18287.0  554065  22755        12   201   0.85  United Kingdom
#
#       TotalScore
# 0       0.871345
# 1       0.042868
# 2       0.210257
# 3       0.075588
# 4       0.835098
# ...          ...
# 4334    0.745204
# 4335    0.484519
# 4336    0.022040
# 4337    0.140899
# 4338    0.124531
#
# [4339 rows x 8 columns]

# %%
# 중복된 ID 값을 하나로 합쳐서 평균을 계산
co_rfm_df_combined = co_rfm_df.groupby('id')[['TotalScore','Recency']].mean().reset_index()
# 나라별로 데이터를 그룹화하고 회원 ID 추출
# co_country_id_df = co_rfm_df.groupby('country')['id'].unique().reset_index()

# 결과 확인
print(co_country_id_df)

# 결과 확인
print(co_rfm_df_combined)
co_rfm_df_combined
# co_country_id_df
# Out:
#                  country                                                 id
# 0              Australia  [12431.0, 12386.0, 12415.0, 12393.0, 12388.0, ...
# 1                Austria  [12429.0, 12370.0, 12373.0, 12414.0, 12817.0, ...
# 2                Bahrain                                 [12355.0, 12353.0]
# 3                Belgium  [12431.0, 12395.0, 12417.0, 12423.0, 12383.0, ...
# 4                 Brazil                                          [12769.0]
# 5                 Canada               [15388.0, 17443.0, 17444.0, 17844.0]
# 6        Channel Islands  [14932.0, 14442.0, 14935.0, 14934.0, 14936.0, ...
# 7                 Cyprus  [12370.0, 12359.0, 13809.0, 12455.0, 12365.0, ...
# 8         Czech Republic                                          [12781.0]
# 9                Denmark  [12429.0, 12372.0, 12435.0, 12394.0, 12406.0, ...
# 10                  EIRE                        [14911.0, 14156.0, 14016.0]
# 11    European Community                                          [15108.0]
# 12               Finland  [12348.0, 12664.0, 12582.0, 12428.0, 12704.0, ...
# 13                France  [12583.0, 12686.0, 12682.0, 12567.0, 12681.0, ...
# 14               Germany  [12662.0, 12738.0, 12427.0, 12600.0, 12712.0, ...
# 15                Greece               [14439.0, 17508.0, 12717.0, 12478.0]
# 16               Iceland                                          [12347.0]
# 17                Israel                        [12653.0, 12688.0, 12512.0]
# 18                 Italy  [12725.0, 12515.0, 12578.0, 12594.0, 12591.0, ...
# 19                 Japan  [12763.0, 12755.0, 12753.0, 12754.0, 12770.0, ...
# 20               Lebanon                                          [12764.0]
# 21             Lithuania                                          [15332.0]
# 22                 Malta                                 [17828.0, 15480.0]
# 23           Netherlands  [12791.0, 14646.0, 12778.0, 12775.0, 12759.0, ...
# 24                Norway  [12433.0, 12350.0, 12352.0, 12432.0, 12444.0, ...
# 25                Poland  [12779.0, 12576.0, 12815.0, 12816.0, 12750.0, ...
# 26              Portugal  [12793.0, 12808.0, 12766.0, 12797.0, 12785.0, ...
# 27                   RSA                                          [12446.0]
# 28          Saudi Arabia                                          [12565.0]
# 29             Singapore                                          [12744.0]
# 30                 Spain  [12557.0, 17097.0, 12540.0, 12551.0, 12417.0, ...
# 31                Sweden  [17404.0, 12483.0, 12676.0, 12639.0, 12697.0, ...
# 32           Switzerland  [13520.0, 12377.0, 12451.0, 12422.0, 12410.0, ...
# 33                   USA               [12733.0, 12607.0, 12646.0, 12558.0]
# 34  United Arab Emirates                                 [17829.0, 12739.0]
# 35        United Kingdom  [17850.0, 13047.0, 13748.0, 15100.0, 15291.0, ...
# 36           Unspecified               [12363.0, 16320.0, 14265.0, 12743.0]
#            id  TotalScore
# 0     12346.0    0.871345
# 1     12347.0    0.042868
# 2     12348.0    0.210257
# 3     12349.0    0.075588
# 4     12350.0    0.835098
# ...       ...         ...
# 4334  18280.0    0.745204
# 4335  18281.0    0.484519
# 4336  18282.0    0.022040
# 4337  18283.0    0.140899
# 4338  18287.0    0.124531
#
# [4339 rows x 2 columns]
#            id  TotalScore
# 0     12346.0    0.871345
# 1     12347.0    0.042868
# 2     12348.0    0.210257
# 3     12349.0    0.075588
# 4     12350.0    0.835098
# ...       ...         ...
# 4334  18280.0    0.745204
# 4335  18281.0    0.484519
# 4336  18282.0    0.022040
# 4337  18283.0    0.140899
# 4338  18287.0    0.124531
#
# [4339 rows x 2 columns]

# %%
co_rfm_df_combined # id를 그룹별로 묶어서 TotalScore를 추출
# Out:
#         id    price  TotalScore
# 0  12540.0  3.84705         1.0

# %%
import numpy as np

l1, l2, l3 = np.percentile(real_df['TotalScore'], [25, 70, 90])
print(l1, l2, l3)
# Out:
# 0.07409845775708526 0.3055068624607468 0.7097238087288109

# %%
def get_level(x):
    if x <= l1:
        return 4
    if x <= l2:
        return 3
    if x <= l3:
        return 2
    return 1

# %%
real_df['Level'] = real_df['TotalScore'].apply(get_level)
real_df
# Out:
#            id invoice   code  quantity  date  price         country  \
# 0     12346.0  541431  23166     74215   325   1.04  United Kingdom
# 1     12347.0  537626  85116        12   367   2.10         Iceland
# 2     12348.0  539318  84992        72   358   0.55         Finland
# 3     12349.0  577609  23112         2    18   7.50           Italy
# 4     12350.0  543037  21908        12   310   2.10          Norway
# ...       ...     ...    ...       ...   ...    ...             ...
# 4334  18280.0  545712  82484         3   277   7.90  United Kingdom
# 4335  18281.0  556464  22037        12   180   0.42  United Kingdom
# 4336  18282.0  562525  21270         1   126  12.75  United Kingdom
# 4337  18283.0  540350  22356         1   337   0.85  United Kingdom
# 4338  18287.0  554065  22755        12   201   0.85  United Kingdom
#
#       TotalScore  Level
# 0       0.871345      1
# 1       0.042868      4
# 2       0.210257      3
# 3       0.075588      3
# 4       0.835098      1
# ...          ...    ...
# 4334    0.745204      1
# 4335    0.484519      2
# 4336    0.022040      4
# 4337    0.140899      3
# 4338    0.124531      3
#
# [4339 rows x 9 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

real_df['Level'] = real_df['Level'].replace([4,3,2,1], ['Bronze', 'Silver','Diamond','VIP'])
real_df
# Out:
#            id invoice   code  quantity  date  price         country  \
# 0     12346.0  541431  23166     74215   325   1.04  United Kingdom
# 1     12347.0  537626  85116        12   367   2.10         Iceland
# 2     12348.0  539318  84992        72   358   0.55         Finland
# 3     12349.0  577609  23112         2    18   7.50           Italy
# 4     12350.0  543037  21908        12   310   2.10          Norway
# ...       ...     ...    ...       ...   ...    ...             ...
# 4334  18280.0  545712  82484         3   277   7.90  United Kingdom
# 4335  18281.0  556464  22037        12   180   0.42  United Kingdom
# 4336  18282.0  562525  21270         1   126  12.75  United Kingdom
# 4337  18283.0  540350  22356         1   337   0.85  United Kingdom
# 4338  18287.0  554065  22755        12   201   0.85  United Kingdom
#
#       TotalScore    Level
# 0       0.871345      VIP
# 1       0.042868   Bronze
# 2       0.210257   Silver
# 3       0.075588   Silver
# 4       0.835098      VIP
# ...          ...      ...
# 4334    0.745204      VIP
# 4335    0.484519  Diamond
# 4336    0.022040   Bronze
# 4337    0.140899   Silver
# 4338    0.124531   Silver
#
# [4339 rows x 9 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

order = ['Bronze', 'Silver','Diamond','VIP']

print(real_df['Level'].value_counts())
# Out:
# Level
# Bronze     1519
# Silver     1518
# Diamond     868
# VIP         434
# Name: count, dtype: int64

# %%
sns.countplot(x='Level', data=real_df, palette='muted', order=order)
plt.title('Level')
plt.show()

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# # scatter plot 대신 countplot을 사용하여 지역별 레벨의 카운트를 시각화
# plt.figure(figsize=(12, 6))
# sns.countplot(x='country', hue='Level', data=real_df, palette='muted')
# plt.title('RFM Level Distribution by Country')
# plt.xlabel('Country')
# plt.ylabel('Count')
# plt.xticks(rotation=45)
# plt.legend(title='Level')
# plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# "United Kingdom"을 제외한 상위 4개 국가 선택
top_countries = real_df[real_df['country'] != 'United Kingdom']['country'].value_counts().nlargest(4).index

# 상위 4개 국가에 해당하는 데이터 필터링
filtered_df = real_df[real_df['country'].isin(top_countries)]

# 그래프 그리기
fig, axes = plt.subplots(1, 2, figsize=(20, 12))

# 왼쪽 그래프: 전체 국가에 대한 RFM Score count
sns.countplot(ax=axes[0], x='country', hue='Level', data=filtered_df, palette='muted')
axes[0].set_title('RFM Score Count for Country (Top 4 Excluding UK)')
axes[0].set_xlabel('Country')

# 오른쪽 그래프: 영국(United Kingdom)에 대한 RFM Score count
uk_df = real_df[real_df['country'] == 'United Kingdom']
sns.countplot(ax=axes[1], x='Level', data=uk_df, palette='muted')
axes[1].set_title('RFM Score Count for United Kingdom')
axes[1].set_xlabel('Level')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 국가별 마케팅 보고서
# -
